# %% [markdown]
# ## Hyperparameter Run Analyzer
#
# Use this notebook to analyze the history dataframes that result from a hyperparameter run. See which hyperparameters led to the lowest losses, and which caused everything to break

# %%
import os
import sys
import pandas as pd

cwd = os.getcwd()

HISTORY_DATAFRAME_FILE = 'estimator_gaze_1m_20d_20hr_57min.pdpckle'
history_path = os.path.join(cwd, '..', '..', 'local', 'models', HISTORY_DATAFRAME_FILE)

# %%
# Load pandas dataframe
df = pd.read_pickle(history_path)

# Sort by loss ascending
df = df.sort_values('loss')

# Print available columns
print(df.columns)

# Select specific sub-columns
# df[['id', 'loss', 'steps', 'batch_norm']]
df[['id', 'loss', 'steps', 'num_rb', 'rb_feat', 'rb_kernel']]
# df[['id', 'loss', 'steps', 'dimred_feat', 'dimred_kernel', 'dimred_stride', 'fc_layers']]
# Out:
# Index(['model_name', 'dropout_keep_prob', 'optimizer_type', 'learning_rate',
#        'num_rb', 'rb_feat', 'rb_kernel', 'batch_norm', 'fc_layers',
#        'dimred_feat', 'dimred_kernel', 'dimred_stride', 'id', 'loss', 'steps',
#        'rmse'],
#       dtype='object')
#                                       id          loss steps num_rb rb_feat  \
# 37  9287ec9d-57f0-4e8a-b852-fda61dd9f33a      0.105091    20      3       8
# 24  3f0c28e6-11b0-4c2e-a619-c9d1d8e7fb13      0.116246    29      3      16
# 13  35ace7e2-3948-4c8a-bc54-6c8164f91924      0.196634     9      2       8
# 19  10b3e012-67d0-4bd5-9a9e-5eefc2768fcb      0.245460    20      2      16
# 42  521e205c-4fdf-4018-bb89-e2535d0545da      0.342018    16      2      16
# 33  88b8cf9a-45a0-445d-aae8-a7a17e23c59f      0.544610    11      3       8
# 25  3f91666c-80cd-4f93-b520-55f0d4b5913f      0.653549    14      2      16
# 4   3be55403-3dab-4028-a73e-a9700fb498c4      0.908387    16      2       8
# 29  c56278c7-074a-4215-9d99-4dedeb9c6c56      1.822435    15      2       8
# 11  c180d1a4-d0b9-411b-a2dc-d336bbe50f7c      2.032039     9      3       8
# 20  1c31707c-0e31-483c-bb79-9a9c6126be43      2.272247    10      2      16
# 15  3ebfa52a-3353-42ef-b3e8-81d4e372c22f      3.109783     6      3      16
# 12  8ffc0d6f-9287-4b1e-b9f3-1603bf52672e      3.697167     9      3       8
# 38  7407b8f4-88aa-4594-939a-e94d57e7833b      5.018184    16      3       8
# 18  4fd06be9-c3ee-4feb-b07a-5ea973ca52b0      6.248931     6      2      16
# 10  edaf82de-8bd1-4c33-b67c-4f45efc5153e      6.819258     6      3      16
# 27  e92bb628-76fc-4982-9892-69567c4ccd50      7.488277    20      2       8
# 30  e2cbd0e7-14fe-4516-856d-5a9f3739b284     10.232779    13      3       8
# 6   5d0b5885-f5e4-44cb-88dc-146024cb171d     11.154335     8      2       8
# 39  5ec71f80-9e17-456e-afbb-1184126b1018     13.367416    14      3       8
# 14  bcd809ae-6321-4cac-8325-da58b61ec8b1     13.419710     6      3       8
# 35  9aa84788-6e93-43c3-bb08-92ad1f4a1702     17.762735     6      3       8
# 1   0c5b5170-e9a1-472b-9020-45e0cb285232     25.525175     6      2       8
# 9   b301f74e-85fd-415e-98c2-94e3d4050841     36.928596    11      2      16
# 2   84be5275-128e-4eb0-8821-d02dc0aa5570     42.214859    21      2       8
# 0   05d75c99-b1cc-4531-af51-1a5f9577e673     51.757805    12      3       8
# 16  39ab84bb-e6c7-4bd0-b29c-f4da59a80344     59.605988     6      2      16
# 28  06499724-73fc-4e9a-b504-c6f38335b416     59.621784     7      2      16
# 31  7742c84b-93d2-4489-a12d-d8f51fbce7cc     64.575134    11      2      16
# 32  25b80a44-06b5-49ef-b292-db959dab641e     66.349426    13      3      16
# 26  49c3b6fc-d163-4058-968c-a07a3b72a069    102.636703    13      3       8
# 8   fa6bc6ff-48bc-4468-98e1-68e3951273ec    121.893456    11      3      16
# 7   0b5986d7-fe28-41b6-b7ac-3308a99728b1    376.309052     6      2      16
# 41  9e64461e-6d65-4c5f-a12a-1cd08447b5a8    625.469421    11      2      16
# 23  0cdd1b2c-ead5-45de-9d68-36552c53d9e9   1021.078735     1      3      16
# 3   4d00ad75-8a85-4f92-b9a2-ebfdd7338e21   1566.543457     1      3      16
# 22  0244dd25-aeef-4bbc-9351-4f082b2a1115   1937.736572     1      3      16
# 34  ceee5d00-9cd2-4b7d-b8be-fe1a9178375d   2019.884033     1      3      16
# 17  636da4e7-53cf-449a-ba9f-4355a241982f   2098.704590     1      2      16
# 40  1c7b43b8-775d-4e02-b91a-e5ea747e7086   3909.385986     1      3      16
# 36  10bc65b0-fd6b-49bf-812a-ec8dea49dc04   5324.231934     0      3       8
# 21  16b2f438-9fc9-4ce9-829d-9e0e21af6416   7196.606934     1      2       8
# 5   9e42811a-e895-44b7-b114-b7ca7158b9ce  16167.596680     1      3       8
#
#    rb_kernel
# 37         4
# 24         3
# 13         3
# 19         3
# 42         4
# 33         3
# 25         3
# 4          4
# 29         3
# 11         3
# 20         4
# 15         4
# 12         3
# 38         4
# 18         3
# 10         4
# 27         3
# 30         4
# 6          3
# 39         3
# 14         3
# 35         3
# 1          3
# 9          3
# 2          3
# 0          4
# 16         3
# 28         3
# 31         3
# 32         3
# 26         4
# 8          4
# 7          3
# 41         4
# 23         4
# 3          4
# 22         3
# 34         4
# 17         3
# 40         3
# 36         3
# 21         4
# 5          3
